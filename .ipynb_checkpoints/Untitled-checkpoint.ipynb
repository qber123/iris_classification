# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris = load_iris(as_frame=True)
list(iris)
# Out:
# ['data',
#  'target',
#  'frame',
#  'target_names',
#  'DESCR',
#  'feature_names',
#  'filename',
#  'data_module']

# %%
iris.data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris.target.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = iris.data[["petal width (cm)"]].values
y = iris.target_names[iris.target] == 'virginica'

log_reg = LogisticRegression(random_state=42)
log_reg.fit(X, y)
# Out:
# LogisticRegression(random_state=42)

# %%
X_new = np.linspace(0, 3, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)
decision_boundary = X_new[y_proba[:, 1] >= 0.5][0, 0]

plt.plot(
    X_new, y_proba[:, 0], "b--", linewidth=2, label="not Iris virginica proba"
)

plt.plot(
    X_new, y_proba[:, 1], "g-", linewidth=2, label="Iris virginica proba"
)

plt.plot(
    [decision_boundary, decision_boundary], [0, 1], "k:", linewidth=2, label="Decision boundary"
)

plt.legend()
plt.show()

# %%
decision_boundary
# Out:
# np.float64(1.6606606606606606)

# %%
log_reg.predict([[1.5], [1.7]])
# Out:
# array([False,  True])

# %%
X_virginica = iris.data["petal length (cm)"][y == 1]
y_virginica = iris.data["petal width (cm)"][y == 1]

X_not_virginica = iris.data["petal length (cm)"][y == 0]
y_not_virginica = iris.data["petal width (cm)"][y == 0]


plt.scatter(X_virginica, y_virginica, color="brown", marker="^")
plt.scatter(X_not_virginica, y_not_virginica, color="b", marker="o")
plt.xlim(3)
plt.ylim(0.75)
# Out:
# (0.75, 2.62)

# %%
X = iris.data[["petal length (cm)", "petal width (cm)"]].values
y = iris["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

softmax_reg = LogisticRegression(C=30, random_state=42)
softmax_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=30, random_state=42)

# %%
softmax_reg.predict([[5, 2]])
# Out:
# array([2])

# %%
softmax_reg.predict_proba([[5, 2]]).round(2)
# Out:
# array([[0.  , 0.04, 0.96]])
